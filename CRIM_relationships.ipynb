# %% [markdown]
# # This notebook collect relationships json file from the server
#
# In this notebook, users can play with visualizations of relationships from server

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import altair as alt # visualization library; see https://altair-viz.github.io/
# import visualizations as viz
# %load_ext autoreload
# %autoreload 2
import visualizations1 as viz

# %% [markdown]
# ## Fetching relationships

# %%
data_relationships = requests.get('http://crimproject.org/data/relationships/').json()
#df = pd.DataFrame(data)
df_relationships = pd.json_normalize(data_relationships)
df_relationships
# Out:
#                                                   url    id  \
# 0        http://crimproject.org/data/relationships/1/     1
# 1        http://crimproject.org/data/relationships/2/     2
# 2        http://crimproject.org/data/relationships/3/     3
# 3        http://crimproject.org/data/relationships/4/     4
# 4        http://crimproject.org/data/relationships/5/     5
# ...                                               ...   ...
# 2660  http://crimproject.org/data/relationships/2683/  2683
# 2661  http://crimproject.org/data/relationships/2684/  2684
# 2662  http://crimproject.org/data/relationships/2685/  2685
# 2663  http://crimproject.org/data/relationships/2686/  2686
# 2664  http://crimproject.org/data/relationships/2692/  2692
#
#                   relationship_type    musical_type   rt_q  rt_q_x  \
# 0                         Quotation            Fuga   True    True
# 1     Non-mechanical transformation            Fuga  False   False
# ...

# %%
files = df_relationships['model_observation.piece.piece_id'].unique()
df_relationships_0011 = df_relationships[df_relationships['model_observation.piece.piece_id'] == files[1]].copy()
files
# Out:
# array(['CRIM_Model_0011', 'CRIM_Model_0018', 'CRIM_Model_0017',
#        'CRIM_Mass_0015_2', 'CRIM_Model_0001', 'CRIM_Model_0020',
#        'CRIM_Model_0009', 'CRIM_Model_0019', 'CRIM_Model_0010',
#        'CRIM_Model_0022', 'CRIM_Model_0002', 'CRIM_Model_0016',
#        'CRIM_Model_0024', 'CRIM_Model_0021', 'CRIM_Mass_0018_1',
#        'CRIM_Model_0008', 'CRIM_Mass_0018_3', 'CRIM_Model_0012',
#        'CRIM_Model_0023', 'CRIM_Model_0015', 'CRIM_Model_0013',
#        'CRIM_Mass_0005_1', 'CRIM_Mass_0016_2', 'CRIM_Mass_0020_3',
#        'CRIM_Model_0006', 'CRIM_Model_0025'], dtype=object)

# %%
# df_relationships = df_relationships[df_relationships['model_observation.piece.piece_id'] == files[15]].copy()
# df_relationships['location'] = df_relationships['model_observation.ema'].str.split("/", n=1, expand=True)[0]
# df_relationships['location'] = df_relationships['location'].str.split(",")
# df_relationships = df_relationships.explode('location')
# df_relationships[['start', 'end']] = df_relationships['location'].str.split("-", expand=True).fillna(method='ffill', axis=1)

# %%
chart, df = viz.plot_relationship_heatmap(df_relationships_0011, 'model_observation.ema')
chart
# Out:
# alt.VConcatChart(...)

# %%
df_relationships

# %% [markdown]
# ## Fetching observations

# %%
data_observations = requests.get('http://crimproject.org/data/observations/').json()
#df = pd.DataFrame(data)
df_observations = pd.json_normalize(data_observations)
df_observations.head()
# Out:
#                                            url  id  \
# 0  http://crimproject.org/data/observations/1/   1
# 1  http://crimproject.org/data/observations/2/   2
# 2  http://crimproject.org/data/observations/3/   3
# 3  http://crimproject.org/data/observations/4/   4
# 4  http://crimproject.org/data/observations/5/   5
#
#                                                  ema musical_type  mt_cf  \
# 0  1-6/1,1,1-2,1-2,2,2/@1,@1-3,@1-3+@1,@1-3+@1-3,...         Fuga  False
# 1  1-6/1,1,1+3,1+3,3,3/@1-4,@1-3,@1-3+@1-4,@1-3+@...         Fuga  False
# 2          5-9/1,1,1-2,2,2/@3,@1-4,@1-2+@4,@1-4,@1-2         Fuga  False
# 3              5-8/1,1+4,1+4,4/@3,@1-4+@4,@1+@1-3,@1         Fuga  False
# 4  5-9,14-18/1,1,1-2,1-2,1-2,3,3,3-4,3-4,3-4/@3,@...         Fuga  False
#
#   mt_cf_voices  mt_cf_dur  mt_cf_mel  mt_sog mt_sog_voices  ...  \
# 0                   False      False   False                ...
# 1                   False      False   False                ...
# ...

# %%
files = df_observations['piece.piece_id'].unique()

# %%
df_observations_0011 = df_observations[df_observations['piece.piece_id'] == files[1]].copy()
chart, df = viz.plot_relationship_heatmap(df_observations_0011, 'ema', 'musical_type')

# %%
df_observations_0011['observer.url'].value_counts()
# Out:
# http://crimproject.org/data/people/CRIM_Person_1014/    21
# http://crimproject.org/data/people/CRIM_Person_1012/     2
# http://crimproject.org/data/people/CRIM_Person_1003/     1
# Name: observer.url, dtype: int64

# %%
chart
# Out:
# alt.VConcatChart(...)
